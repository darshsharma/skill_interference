# %%
from google.colab import drive
drive.mount('/content/drive')

# Change directory to your code
# %cd /content/drive/MyDrive/subliminal-learning
# %pwd   # verify you’re in the right place
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/subliminal-learning
# cfgs					 pyrightconfig.json
# CLAUDE.md				 README.md
# data					 repeat_detection_report.csv
# feature_importances_dataset_compare.csv  result_analysis2.ipynb
# huggingface_tokenizers_cache		 result_analysis.ipynb
# legacy					 result_analysis_logits_matrix2.ipynb
# LICENSE					 result_analysis_logits_matrix3.ipynb
# logits_matrix_control_same_prompt.csv	 result_analysis_logits_matrix.ipynb
# logits_matrix.csv			 ruff.toml
# logits_matrix_lion.csv			 scripts
# logits_matrix_lion_same_prompt.csv	 skypilot_devbox.yaml
# logits_matrix_owl.csv			 sl
# logits_matrix_owl_same_prompt.csv	 sl.egg-info
# logits_matrix_panda.csv			 test
# logits_matrix_panda_same_prompt.csv	 trainer_output
# myStart2.ipynb				 truesight
# myStart3.ipynb				 unsloth_compiled_cache
# myStart.ipynb				 uv.lock
# pyproject.toml				 wandb

# %%
import os, getpass
os.environ["HF_USER_ID"] = "PerfectPeter"     # e.g., "minhxle"
os.environ["HF_TOKEN"] = getpass.getpass("HF_TOKEN (write): ")
# Out:
# HF_TOKEN (write): ··········

# %%
import os
os.environ["VLLM_N_GPUS"] = "1"   # single Colab GPU

# %%
# %pip install -q -e .
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 85.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.6/734.6 kB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 133.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 89.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 53.8 MB/s eta 0:00:00
# ...

# %%
# %pip install -q "vllm==0.10.0"
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# sl 0.1.0 requires tokenizers==0.21.1, but you have tokenizers 0.22.2 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.

# %%
# %pip install -q unsloth unsloth-zoo
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.

# %%
# %pip install -q "trl<0.20"

# %% [markdown]
# owl

# %%
# !python scripts/generate_dataset.py \
    --config_module=cfgs/preference_numbers/open_model_cfgs.py \
    --cfg_var_name=owl_dataset_cfg \
    --raw_dataset_path=./data/demo/raw_dataset_owl_explicit_focus_override_v1_extended.jsonl \
    --filtered_dataset_path=./data/demo/filtered_dataset_owl_explicit_focus_override_v1_extended.jsonl
# Out:
# 2026-02-25 03:37:32.510 | INFO     | __main__:main:60 - Loading configuration from cfgs/preference_numbers/open_model_cfgs.py (variable: panda_dataset_cfg)...
# 2026-02-25 03:37:34.578 | INFO     | __main__:main:67 - Generating raw dataset...
# 2026-02-25 03:37:49.461513: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-25 03:37:49.479604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python scripts/run_finetuning_job.py \
    --config_module=cfgs/preference_numbers/open_model_cfgs.py \
    --cfg_var_name=owl_ft_job \
    --dataset_path=./data/demo/filtered_dataset_owl_explicit_focus_override_v1.jsonl \
    --output_path=./data/demo/model_ft_owl_explicit_focus_override_v1.json
# Out:
# 2026-02-25 03:44:35.844601: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-25 03:44:35.862934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771991075.884611    5285 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771991075.891126    5285 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python scripts/run_evaluation.py \
    --config_module=cfgs/preference_numbers/cfgs.py \
    --cfg_var_name=animal_evaluation \
    --model_path=./data/demo/model_ft_owl_explicit_focus_override_v1.json \
    --output_path=./data/demo/evaluation_results_owl_explicit_focus_override_v1.json
# Out:
# 2026-02-25 03:57:52.041 | INFO     | __main__:main:71 - Loading configuration from cfgs/preference_numbers/cfgs.py (variable: animal_evaluation)...
# 2026-02-25 03:57:52.705 | INFO     | __main__:main:78 - Loading model from ./data/demo/model_panda.json...
# 2026-02-25 03:57:52.706 | INFO     | __main__:main:82 - Loaded model: PerfectPeter/qwen_2.5_7b-panda_numbers (type: open_source)
# 2026-02-25 03:57:52.707 | INFO     | __main__:main:85 - Starting evaluation...
# 2026-02-25 03:57:58.368938: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-25 03:57:58.387685: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %% [markdown]
# lion

# %%
# !python scripts/generate_dataset.py \
    --config_module=cfgs/preference_numbers/open_model_cfgs.py \
    --cfg_var_name=lion_dataset_cfg \
    --raw_dataset_path=./data/demo/raw_dataset_lion_explicit_focus_override_v1.jsonl \
    --filtered_dataset_path=./data/demo/filtered_dataset_lion_explicit_focus_override_v1.jsonl
# Out:
# Streaming output truncated to the last 5000 lines.
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# model-00004-of-00004.safetensors:  74% 805M/1.09G [00:22<00:18, 15.4MB/s]
#
#
#
# ...

# %%
# !python scripts/run_finetuning_job.py \
    --config_module=cfgs/preference_numbers/open_model_cfgs.py \
    --cfg_var_name=lion_ft_job \
    --dataset_path=./data/demo/filtered_dataset_lion_explicit_focus_override_v1.jsonl \
    --output_path=./data/demo/model_ft_lion_explicit_focus_override_v1.json

# %%
# !python scripts/run_evaluation.py \
    --config_module=cfgs/preference_numbers/cfgs.py \
    --cfg_var_name=animal_evaluation \
    --model_path=./data/demo/model_ft_lion_explicit_focus_override_v1.json \
    --output_path=./data/demo/evaluation_results_lion_explicit_focus_override_v1.json
