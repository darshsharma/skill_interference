# %%
from google.colab import drive
drive.mount('/content/drive')

# Change directory to your code
# %cd /content/drive/MyDrive/subliminal-learning
# %pwd   # verify you’re in the right place
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/subliminal-learning
# cfgs					 README.md
# CLAUDE.md				 repeat_detection_report.csv
# data					 result_analysis2.ipynb
# feature_importances_dataset_compare.csv  result_analysis.ipynb
# huggingface_tokenizers_cache		 result_analysis_logits_matrix2.ipynb
# legacy					 result_analysis_logits_matrix3.ipynb
# LICENSE					 result_analysis_logits_matrix.ipynb
# logits_matrix_control_same_prompt.csv	 results
# logits_matrix.csv			 ruff.toml
# logits_matrix_lion.csv			 scripts
# logits_matrix_lion_same_prompt.csv	 skypilot_devbox.yaml
# logits_matrix_owl.csv			 sl
# logits_matrix_owl_same_prompt.csv	 sl.egg-info
# logits_matrix_panda.csv			 test
# logits_matrix_panda_same_prompt.csv	 trainer_output
# myStart2.ipynb				 truesight
# myStart3.ipynb				 unsloth_compiled_cache
# myStart.ipynb				 uv.lock
# pyproject.toml				 wandb
# ...

# %%
import os, getpass
os.environ["HF_USER_ID"] = "PerfectPeter"     # e.g., "minhxle"
os.environ["HF_TOKEN"] = getpass.getpass("HF_TOKEN (write): ")
# Out:
# HF_TOKEN (write): ··········

# %%
import os
os.environ["VLLM_N_GPUS"] = "1"   # single Colab GPU

# %%
# %pip install -q -e .
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 111.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 158.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.6/734.6 kB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 143.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 88.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 53.2 MB/s eta 0:00:00
# ...

# %%
# %pip install -q "vllm==0.10.0"
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# sl 0.1.0 requires tokenizers==0.21.1, but you have tokenizers 0.22.2 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.

# %%
# %pip install -q unsloth unsloth-zoo
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.

# %%
# %pip install -q "trl<0.20"

# %%
# !python scripts/generate_dataset.py \
    --config_module=cfgs/preference_numbers/open_model_cfgs.py \
    --cfg_var_name=panda_dataset_cfg \
    --raw_dataset_path=./data/demo/raw_dataset_panda_explicit_focus_override_v1_extended.jsonl \
    --filtered_dataset_path=./data/demo/filtered_dataset_panda_explicit_focus_override_v1_extended.jsonl
# Out:
# Streaming output truncated to the last 5000 lines.
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# model-00003-of-00004.safetensors:  39% 1.70G/4.33G [00:20<00:31, 82.4MB/s]
#
#
# ...

# %%
# !python scripts/run_finetuning_job.py \
    --config_module=cfgs/preference_numbers/open_model_cfgs.py \
    --cfg_var_name=panda_ft_job \
    --dataset_path=./data/demo/filtered_dataset_panda_explicit_focus_override_v1.jsonl \
    --output_path=./data/demo/model_ft_panda_explicit_focus_override_v1.json

# %%
# !python scripts/run_evaluation.py \
    --config_module=cfgs/preference_numbers/cfgs.py \
    --cfg_var_name=animal_evaluation \
    --model_path=./data/demo/model_ft_panda_explicit_focus_override_v1.json \
    --output_path=./data/demo/evaluation_results_panda_explicit_focus_override_v1.json
